# %% [markdown]
# (https://stackoverflow.com/questions/20033396/how-to-visualize-95-confidence-interval-in-matplotlib#20039978)
#
# https://stackoverflow.com/questions/43016380/python-matplotlib-plotting-sample-means-in-bar-chart-with-confidence-intervals-b#43026658
#
# (http://www.nairaland.com/67316/what-some-issues-discussed-during)
#
# (http://matplotlib.org/api/pyplot_api.html?highlight=pyplot%20bar#matplotlib.pyplot.bar)
#
# [`html colors`](https://www.computerhope.com/htmcolor.htm)
#
# [`confidence interval quora`](https://www.quora.com/What-is-a-confidence-interval-in-laymans-terms)
#
# http://people.stern.nyu.edu/churvich/MBA/Handouts/10-CI(1).pdf
#
# [`events`](http://matplotlib.org/api/backend_bases_api.html?highlight=event#matplotlib.backend_bases.FigureCanvasBase.mpl_connect)
#
# (http://matplotlib.org/users/event_handling.html?highlight=event)
#
# [`axes methods`](http://matplotlib.org/api/axes_api.html#axes-class)
#
# [`listed colormap`](http://matplotlib.org/devdocs/tutorials/colors/colorbar_only.html#sphx-glr-tutorials-colors-colorbar-only-py)
#
#
# **Easiest option:** Implement the bar coloring as described above - a color scale with only three colors, (e.g. blue, white, and red). Assume the user provides the y axis value of interest as a parameter or variable.
#
#
# **Harder option:** Implement the bar coloring as described in the paper, where the color of the bar is actually based on the amount of data covered (e.g. a gradient ranging from dark blue for the distribution being certainly below this y-axis, to white if the value is certainly contained, to dark red if the value is certainly not contained as the distribution is above the axis).
#
# **Even Harder option:** Add interactivity to the above, which allows the user to click on the y axis to set the value of interest. The bar colors should change with respect to what value the user has selected.
#
# **Hardest option:** Allow the user to interactively set a range of y values they are interested in, and recolor based on this (e.g. a y-axis band, see the paper for more details).

# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib as mpl
import scipy.stats as ss

# from plot_normal_data import *
# from plot_normal_basic import *
# from plot_normal_chameleon import *
from plot_normal_colordance import *

# %%
fig = plt.figure()
ax = fig.add_axes([0.15, 0.15, 0.6, 0.80], frame_on=True)
ax2 = fig.add_axes([0.4, 0.05, 0.4, 0.025], frame_on=True)
interactive_basic(ax, ax2, dff, cm_scheme[0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
draw_line()
# Out:
# Enter a value of y between 717.0711754662223 and 717.0711754662223 250
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-422cccacb7a1> in <module>()
# ----> 1 draw_line()
#
# C:\Users\Chidimma\Dropbox\coursera_python_for_data_science_matplotlib\plot_normal_basic.py in draw_line()
#      72     y_value = int(input('Enter a value of y between {} and {} '
#      73                         .format(np.abs(min_value), np.abs(min_value))))
# ---> 74     ax.axhline(y=y_value, color='#3D3C3A', zorder=20)
#      75
#      76 if __name__ == "__main__":
#
# NameError: name 'ax' is not defined

# %% [markdown]
# print(dff.head())
# print(dff.describe())

# %%
whos

# %%
def chameleon(event):
    """Change color of chameleon"""
    ax.cla()
    ax2.cla()
    interactive_chameleon(ax, ax2, dff, event.ydata, cm_scheme[5])

fig = plt.figure(figsize=(8, 6), facecolor='lightblue')
ax = fig.add_axes([0.15, 0.15, 0.6, 0.80], frame_on=True)
ax2 = fig.add_axes([0.4, 0.05, 0.4, 0.025], frame_on=True)
interactive_chameleon(ax, ax2, dff, 50, cm_scheme[5])
plt.gcf().canvas.mpl_connect('button_press_event', chameleon)
